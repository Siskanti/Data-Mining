# %% [markdown]
# Nama : Siskanti
#
# NIM : H071201064
#
# Prodi : Sistem Informasi

# %% [markdown]
# # **Data Citra**

# %% [markdown]
# **Processing Data Tidat Terstruktur**

# %%
import cv2
from matplotlib import pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
from tensorflow.keras.applications.resnet_v2 import preprocess_input as preprocess_resnetv2
import numpy as np
import os
from PIL import Image

# %% [markdown]
# 1. Mengimport gambar dan menampilkannya

# %% [markdown]
# Disini kita akan mengimpor gambar lalu menampilkannya. Buat variabel image, kemudian upload gambar yang akan ditampilkan. kemudian tambahkan parameternya dengan format namagambar.jpg / namagambar.jenisgambar. setelah itu kita plot untuk menampilkan gambarnya.

# %%
image = cv2.imread('17220-batu-ganjal-pintu-dihargai-rp-15-miliar.jpg')
plt.imshow(image)

# %% [markdown]
# pada bagian ini, ketika kita akan convert gambarnya ke RGB. disini penting karena ada arsitektur untuk mengolah data tidak terstruktur. karena biasanya ada yang diminta format nya itu seperti RGB, BGR, graiscal

# %%
image_cvtresult = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_cvtresult)

# %%
r,g,b = cv2.split(image_cvtresult)
plt.imshow(b)

# %% [markdown]
# untuk mmebuat suatu pemrosesan citra menggunakan algoritma deep learning kadang data yang banyak itu dari gambar itu  dalam  folder. kemudian kita punya 2 cara
#
# 1. buat format seperti excel
# 2. kadang dimuat dalam suatu array
#
# citra ini sebenarnya kumpulan angka. angka ini merupakan intensitas kecerahan citra tersebut. jadi dia bisa di ubah jadi array. kalau diubah jadi  array akan lebih mudah

# %%
image_array = img_to_array(image_cvtresult)
print(image_array)
# Out:
# [[[171. 185. 198.]
#   [171. 185. 198.]
#   [171. 185. 198.]
#   ...
#   [121. 125. 110.]
#   [125. 129. 114.]
#   [127. 131. 116.]]
#
#  [[172. 186. 199.]
#   [172. 186. 199.]
#   [172. 186. 199.]
#   ...
#   [120. 124. 109.]
#   [124. 128. 113.]
#   [127. 131. 116.]]
#
#  [[172. 186. 199.]
#   [172. 186. 199.]
#   [172. 186. 199.]
#   ...
#   [119. 123. 108.]
#   [123. 127. 112.]
#   [126. 130. 115.]]
#
#  ...
#
#  [[ 49.  54.  58.]
#   [ 48.  53.  57.]
#   [ 46.  51.  55.]
#   ...
#   [ 51.  52.  46.]
#   [ 51.  52.  46.]
#   [ 52.  53.  47.]]
#
#  [[ 47.  52.  56.]
#   [ 46.  51.  55.]
#   [ 45.  50.  54.]
#   ...
#   [ 48.  49.  43.]
#   [ 50.  51.  45.]
#   [ 53.  54.  48.]]
#
#  [[ 44.  49.  53.]
#   [ 43.  48.  52.]
#   [ 43.  48.  52.]
#   ...
#   [ 44.  45.  39.]
#   [ 47.  48.  42.]
#   [ 50.  51.  45.]]]

# %%
fig = plt.figure(num = None, figsize=(8, 8))

image_grayscale_temp = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_grayscale = cv2.cvtColor(image_grayscale_temp, cv2. COLOR_GRAY2RGB)

image_hsv = cv2.cvtColor(image_cvtresult, cv2.COLOR_RGB2HSV)

ax = fig.add_subplot(2, 2, 1)
plt.imshow(image)

ax = fig.add_subplot(2, 2, 2)
plt.imshow(image_cvtresult)

ax = fig.add_subplot(2, 2, 3)
plt.imshow(image_grayscale)

ax = fig.add_subplot(2, 2, 4)
plt.imshow(image_hsv)

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Format yang BGR

# %%
ax = fig.add_subplot(2, 2, 1)
plt.imshow(image)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Format yang RGB

# %%
ax = fig.add_subplot(2, 2, 2)
plt.imshow(image_cvtresult)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.
# <function matplotlib.pyplot.show>

# %% [markdown]
# Format yang grayscale

# %%
ax = fig.add_subplot(2, 2, 3)
plt.imshow(image_grayscale)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Format yang HSV

# %%
ax = fig.add_subplot(2, 2, 4)
plt.imshow(image_hsv)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# untuk melihat histogramnya

# %%
fig = plt.figure(num = None, figsize=(8, 8))

image_grayscale_temp = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_grayscale = cv2.cvtColor(image_grayscale_temp, cv2. COLOR_GRAY2RGB)

image_hsv = cv2.cvtColor(image_cvtresult, cv2.COLOR_RGB2HSV)

ax = fig.add_subplot(2, 2, 1)
plt.hist(image.ravel(),256,[0,256])

ax = fig.add_subplot(2, 2, 2)
plt.hist(image_cvtresult.ravel(),256,[0,256])

ax = fig.add_subplot(2, 2, 3)
plt.hist(image_grayscale.ravel(),256,[0,256])

ax = fig.add_subplot(2, 2, 4)
plt.hist(image_hsv.ravel(),256,[0,256])

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image_resize = cv2.resize(image_cvtresult, (150, 150))
plt.imshow(image_resize)

# %%
base_directory = '/content'
augmented_directory = os.path.join(base_directory, "augmented_result")
os.mkdir(augmented_directory)

# %%
datagen = ImageDataGenerator(
    rotation_range = 45,
    width_shift_range = 0.5
)

# %%
path = "/content/drive/MyDrive/17220-batu-ganjal-pintu-dihargai-rp-15-miliar"
size = 150
dataset = []
image_dir = os.listdir(path)

img = io.imread(f"{path}/{image_dir[0]}")
img = Image.fromarray(img, 'RGB')
img = img.resize((size, size))
dataset.append(np.array(img))
x = np.array(dataset)

# %%
i = 0
for j in datagen.flow(x, batch_size = 32,
                      save_to_dir = "/content/augmented_result/",
                      save_prefix = "aug_rslt",
                      save_format = "png"):

  i += 1
  if i > 30:
    break

# %%
image1 = cv2.GaussianBlur(image_cvtresult, (3,3), 0)
rgb_dst = cv2.fastNlMeansDenoisingColored(image1, None, 10, 10, 7, 21)

plt.subplot(121),plt.imshow(image_cvtresult)
plt.subplot(122),plt.imshow(rgb_dst)

plt.show()
